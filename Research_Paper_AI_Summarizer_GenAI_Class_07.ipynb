# %%
# !pip -q install langchain langchain-groq gradio pymupdf python-dotenv
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.7/25.7 MB 39.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.5/137.5 kB 9.0 MB/s eta 0:00:00

# %%
import fitz
import os
import gradio as gr

from langchain_groq import ChatGroq
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

# %%
from google.colab import userdata
os.environ["GROQ_API_KEY"] = userdata.get('Groq_API_Key')

# %%
llm = ChatGroq(
    model="llama-3.1-8b-instant",
    temperature=0.2
)

# %%
def extract_text(pdf):

    doc = fitz.open(pdf.name)

    text = ""

    for page in doc:
        text += page.get_text()

    return text

# %%
prompt = ChatPromptTemplate.from_template("""

You are an expert Research Assistant.

Analyze the following research paper.

Provide:

1. Title

2. Research Objective

3. Abstract Summary

4. Methodology

5. Dataset Used

6. Algorithms / Models

7. Key Results

8. Advantages

9. Limitations

10. Future Work

11. Five Important Keywords

Paper:

{text}

""")

# %%
chain = prompt | llm | StrOutputParser()

# %%
def summarize(pdf):

    text = extract_text(pdf)

    if len(text) > 15000:
        text = text[:15000]

    result = chain.invoke({
        "text": text
    })

    return result

# %%
# css = """

# body{
# background:#0F172A;
# }

# .gradio-container{
# background:#0F172A;
# color:white;
# }

# """

# demo = gr.Interface(

#     fn=summarize,

#     inputs=gr.File(
#         label="Upload Research Paper (PDF)",
#         file_types=[".pdf"]
#     ),

#     outputs=gr.Markdown(
#         label="AI Summary"
#     ),

#     title="📄 Research Paper AI Summarizer",

#     description="""
# Upload any research paper and receive a structured AI-generated summary powered by **Groq + LangChain**.
# """,

#     theme=gr.themes.Soft(),

#     css=css

# )

# demo.launch(debug=True)

# %%
# import gradio as gr

# css = """
# @import url('https://fonts.googleapis.com/css2?family=Poppins:wght@300;400;500;600;700&display=swap');

# body{
#     background:#0B1F3A;
#     font-family:'Poppins',sans-serif;
# }

# .gradio-container{
#     background:#0B1F3A !important;
#     color:white;
#     font-family:'Poppins',sans-serif;
# }

# h1,h2,h3{
#     color:#F4C542 !important;
#     text-align:center;
#     font-weight:700;
# }

# p{
#     color:white;
# }

# .gr-box{
#     border-radius:18px;
# }

# .gr-panel{
#     background:#13294B !important;
#     border-radius:18px;
#     border:1px solid #F4C542;
#     box-shadow:0px 8px 25px rgba(0,0,0,.35);
# }

# button{
#     background:#F4C542 !important;
#     color:#0B1F3A !important;
#     font-size:18px !important;
#     font-weight:600 !important;
#     border-radius:12px !important;
#     border:none !important;
#     transition:0.3s;
# }

# button:hover{
#     background:#FFD84D !important;
#     transform:scale(1.03);
# }

# textarea{
#     background:#10284A !important;
#     color:white !important;
#     border-radius:12px !important;
#     border:1px solid #F4C542 !important;
# }

# input{
#     background:#10284A !important;
#     color:white !important;
# }

# footer{
#     visibility:hidden;
# }

# ::-webkit-scrollbar{
#     width:10px;
# }

# ::-webkit-scrollbar-thumb{
#     background:#F4C542;
#     border-radius:10px;
# }

# ::-webkit-scrollbar-track{
#     background:#10284A;
# }
# """

# %%
# css = """

# /* ==============================
#    IMPORT FONT
# ================================= */

# @import url('https://fonts.googleapis.com/css2?family=Poppins:wght@300;400;500;600;700;800&display=swap');


# /* ==============================
#    ROOT COLORS
# ================================= */

# :root{

# --bg:#07162D;
# --card:#10284A;
# --card2:#173A63;

# --primary:#FFC93C;
# --secondary:#FFD95A;

# --text:#FFFFFF;
# --text2:#D6D6D6;

# --shadow:0 12px 35px rgba(0,0,0,.45);

# }


# /* ==============================
#    BACKGROUND
# ================================= */

# body{

# background:
# radial-gradient(circle at top left,#173A63 0%,transparent 35%),
# radial-gradient(circle at bottom right,#10284A 0%,transparent 40%),
# #07162D;

# font-family:'Poppins',sans-serif;

# color:var(--text);

# }


# /* ==============================
#    APP CONTAINER
# ================================= */

# .gradio-container{

# background:transparent !important;

# font-family:'Poppins',sans-serif;

# max-width:1400px !important;

# margin:auto;

# }


# /* ==============================
#    HEADINGS
# ================================= */

# h1{

# font-size:48px !important;

# font-weight:800 !important;

# background:linear-gradient(90deg,#FFD95A,#FFC93C,#F5B000);

# -webkit-background-clip:text;

# -webkit-text-fill-color:transparent;

# text-align:center;

# margin-bottom:5px;

# }

# h2{

# color:#FFD95A;

# font-size:28px;

# font-weight:700;

# }

# h3{

# color:#FFD95A;

# font-weight:600;

# }


# /* ==============================
#    TEXT
# ================================= */

# p{

# color:#E8E8E8;

# font-size:16px;

# line-height:1.8;

# }


# /* ==============================
#    CARDS
# ================================= */

# .gr-group,
# .gr-box,
# .gr-panel{

# background:rgba(16,40,74,.82)!important;

# backdrop-filter:blur(18px);

# border-radius:22px;

# border:1px solid rgba(255,201,60,.35);

# box-shadow:var(--shadow);

# padding:18px;

# transition:.35s;

# }

# .gr-group:hover,
# .gr-box:hover,
# .gr-panel:hover{

# transform:translateY(-4px);

# box-shadow:0 18px 40px rgba(0,0,0,.55);

# }


# /* ==============================
#    BUTTONS
# ================================= */

# button{

# background:linear-gradient(135deg,#FFD95A,#FFC93C);

# color:#07162D !important;

# font-size:17px !important;

# font-weight:700 !important;

# padding:14px 22px !important;

# border:none !important;

# border-radius:14px !important;

# transition:.35s;

# box-shadow:0 6px 20px rgba(255,201,60,.45);

# }

# button:hover{

# transform:translateY(-2px) scale(1.03);

# box-shadow:0 10px 28px rgba(255,201,60,.65);

# filter:brightness(1.05);

# }


# /* ==============================
#    FILE UPLOAD
# ================================= */

# .upload-box{

# border:2px dashed #FFC93C;

# border-radius:18px;

# background:#10284A;

# }


# /* ==============================
#    INPUTS
# ================================= */

# textarea,
# input{

# background:#0E2340 !important;

# color:white !important;

# border-radius:14px !important;

# border:1px solid rgba(255,201,60,.35)!important;

# font-size:15px;

# padding:12px;

# transition:.25s;

# }

# textarea:focus,
# input:focus{

# border:1px solid #FFD95A!important;

# box-shadow:0 0 15px rgba(255,217,90,.45);

# }


# /* ==============================
#    MARKDOWN OUTPUT
# ================================= */

# .markdown{

# background:#10284A;

# border-radius:18px;

# padding:22px;

# color:white;

# }


# /* ==============================
#    TABLES
# ================================= */

# table{

# border-radius:15px;

# overflow:hidden;

# }

# th{

# background:#FFC93C;

# color:#07162D;

# }

# td{

# background:#173A63;

# color:white;

# }


# /* ==============================
#    SCROLLBAR
# ================================= */

# ::-webkit-scrollbar{

# width:10px;

# }

# ::-webkit-scrollbar-track{

# background:#10284A;

# }

# ::-webkit-scrollbar-thumb{

# background:linear-gradient(#FFD95A,#FFC93C);

# border-radius:20px;

# }


# /* ==============================
#    LINKS
# ================================= */

# a{

# color:#FFD95A;

# text-decoration:none;

# }

# a:hover{

# color:white;

# }


# /* ==============================
#    FOOTER
# ================================= */

# footer{

# visibility:hidden;

# }


# /* ==============================
#    ANIMATIONS
# ================================= */

# @keyframes fadeUp{

# from{

# opacity:0;

# transform:translateY(20px);

# }

# to{

# opacity:1;

# transform:translateY(0);

# }

# }

# .gradio-container{

# animation:fadeUp .8s ease;

# }


# /* ==============================
#    GLOW EFFECT
# ================================= */

# .glow{

# box-shadow:
# 0 0 18px rgba(255,201,60,.35),
# 0 0 35px rgba(255,201,60,.15);

# }


# /* ==============================
#    HEADER LINE
# ================================= */

# .gold-line{

# height:4px;

# background:linear-gradient(90deg,#FFC93C,#FFD95A,#FFC93C);

# border-radius:50px;

# margin-bottom:18px;

# }


# /* ==============================
#    RESPONSIVE
# ================================= */

# @media(max-width:768px){

# h1{

# font-size:34px!important;

# }

# button{

# width:100%;

# }

# }

# """

# %%
css = """
/*==================================================
      GOOGLE FONT
==================================================*/
@import url('https://fonts.googleapis.com/css2?family=Poppins:wght@300;400;500;600;700;800&display=swap');

/*==================================================
      COLOR SYSTEM (60-30-10)
==================================================*/
:root{
    --navy:#081C2D;
    --navy2:#12344D;

    --teal:#0F766E;
    --teal-light:#14B8A6;

    --gold:#F4C430;
    --gold-light:#FFD54F;

    --white:#F8FAFC;
    --gray:#CBD5E1;
}

/*==================================================
      BODY
==================================================*/
body{
    font-family:'Poppins',sans-serif;
    background:
        radial-gradient(circle at top left,#12344D 0%,transparent 35%),
        radial-gradient(circle at bottom right,#0F766E 0%,transparent 30%),
        #081C2D;
}

/*==================================================
      CONTAINER
==================================================*/
.gradio-container{
    font-family:'Poppins',sans-serif !important;
    background:transparent !important;
    max-width:1400px !important;
    margin:auto;
}

/*==================================================
      TITLES
==================================================*/
h1{
    font-size:50px !important;
    font-weight:800 !important;
    text-align:center;

    background:linear-gradient(
        90deg,
        #FFD54F,
        #F4C430,
        #14B8A6
    );

    -webkit-background-clip:text;
    -webkit-text-fill-color:transparent;

    margin-bottom:10px;
}

h2{
    color:#F4C430 !important;
    font-weight:700;
}

h3{
    color:#14B8A6 !important;
}

/*==================================================
      TEXT
==================================================*/
p, label{
    color:#CBD5E1 !important;
}

/*==================================================
      CARDS
==================================================*/
.gr-group,
.gr-box,
.gr-panel{
    background:rgba(18,52,77,.80)!important;
    backdrop-filter:blur(15px);

    border-radius:18px;
    border:1px solid rgba(20,184,166,.30);

    box-shadow:
        0 10px 35px rgba(0,0,0,.40);

    transition:.3s;
}

.gr-group:hover,
.gr-box:hover,
.gr-panel:hover{
    transform:translateY(-5px);
    border-color:#14B8A6;
}

/*==================================================
      BUTTON
==================================================*/
button{

    background:linear-gradient(
        135deg,
        #F4C430,
        #FFD54F
    ) !important;

    color:#081C2D !important;

    font-size:17px !important;
    font-weight:700 !important;

    border:none !important;
    border-radius:12px !important;

    transition:.3s;

    box-shadow:
        0 8px 20px rgba(244,196,48,.35);

}

button:hover{

    transform:translateY(-3px);

    background:linear-gradient(
        135deg,
        #FFD54F,
        #FFE16A
    ) !important;

    box-shadow:
        0 12px 28px rgba(244,196,48,.55);

}

/*==================================================
      INPUTS
==================================================*/
input,
textarea{

    background:#102C44 !important;

    color:white !important;

    border-radius:12px !important;

    border:1px solid rgba(20,184,166,.35)!important;

}

input:focus,
textarea:focus{

    border-color:#FFD54F !important;

    box-shadow:
        0 0 15px rgba(20,184,166,.40);

}

/*==================================================
      FILE UPLOAD
==================================================*/
input[type=file]{

    background:#12344D!important;

    border:2px dashed #14B8A6!important;

    border-radius:15px!important;

    padding:15px;

}

/*==================================================
      MARKDOWN OUTPUT
==================================================*/
.markdown{

    background:rgba(15,118,110,.10);

    border-left:5px solid #F4C430;

    border-radius:15px;

    padding:20px;

    color:white;

}

/*==================================================
      SCROLLBAR
==================================================*/
::-webkit-scrollbar{
    width:10px;
}

::-webkit-scrollbar-track{
    background:#12344D;
}

::-webkit-scrollbar-thumb{
    background:linear-gradient(#14B8A6,#F4C430);
    border-radius:20px;
}

/*==================================================
      FOOTER
==================================================*/
footer{
    visibility:hidden;
}

/*==================================================
      ANIMATION
==================================================*/
@keyframes fadeIn{
    from{
        opacity:0;
        transform:translateY(25px);
    }
    to{
        opacity:1;
        transform:translateY(0);
    }
}

.gradio-container{
    animation:fadeIn .8s ease;
}

/*==================================================
      RESPONSIVE
==================================================*/
@media(max-width:768px){

    h1{
        font-size:34px !important;
    }

    button{
        width:100%;
    }

}
"""

# %%
with gr.Blocks(
    theme=gr.themes.Soft(
        primary_hue="yellow",
        secondary_hue="teal",
        neutral_hue="slate",
    ),
    css=css,
    title="Research Paper AI Summarizer"
) as demo:

    # ==========================================
    # HERO SECTION
    # ==========================================

    gr.HTML("""
    <div style="text-align:center;padding:25px 10px 15px 10px;">

        <h1 style="font-size:48px;font-weight:800;margin-bottom:8px;">
            📄 Research Paper AI Summarizer
        </h1>

        <p style="font-size:18px;color:#CBD5E1;margin-bottom:25px;">
            Transform lengthy research papers into concise, structured insights
            using <b style="color:#FFD54F;">Groq</b>,
            <b style="color:#14B8A6;">LangChain</b>,
            and
            <b style="color:#FFD54F;">Artificial Intelligence</b>.
        </p>

    </div>
    """)

    # ==========================================
    # FEATURE CARDS
    # ==========================================

    gr.HTML("""

    <div style="display:flex;
                justify-content:center;
                gap:18px;
                flex-wrap:wrap;
                margin-bottom:25px;">

        <div style="
            background:#12344D;
            padding:16px 28px;
            border-radius:16px;
            border:1px solid #14B8A6;
            min-width:180px;
            text-align:center;">

            <h3>⚡ Fast AI</h3>
            <p>Groq Llama 3.1</p>

        </div>

        <div style="
            background:#12344D;
            padding:16px 28px;
            border-radius:16px;
            border:1px solid #14B8A6;
            min-width:180px;
            text-align:center;">

            <h3>📑 Smart Summary</h3>
            <p>11 Structured Sections</p>

        </div>

        <div style="
            background:#12344D;
            padding:16px 28px;
            border-radius:16px;
            border:1px solid #14B8A6;
            min-width:180px;
            text-align:center;">

            <h3>🧠 AI Powered</h3>
            <p>LangChain Pipeline</p>

        </div>

    </div>

    """)

    # ==========================================
    # MAIN LAYOUT
    # ==========================================

    with gr.Row(equal_height=True):

        # -----------------------
        # LEFT PANEL
        # -----------------------

        with gr.Column(scale=1):

            gr.Markdown("## 📂 Upload Paper")

            pdf = gr.File(
                label="Choose PDF",
                file_types=[".pdf"],
                height=220
            )

            summarize_btn = gr.Button(
                "✨ Generate AI Summary",
                variant="primary",
                size="lg"
            )

            clear_btn = gr.ClearButton(
                components=[pdf],
                value="🗑 Clear"
            )

        # -----------------------
        # RIGHT PANEL
        # -----------------------

        with gr.Column(scale=2):

            gr.Markdown("## 📋 AI Generated Summary")

            output = gr.Markdown(
                value="""
### 👋 Welcome

Upload a research paper to receive:

- 📌 Research Objective
- 📚 Abstract Summary
- 🔬 Methodology
- 📊 Dataset
- 🤖 Algorithms Used
- 📈 Results
- ✅ Advantages
- ⚠ Limitations
- 🚀 Future Work
- 🔑 Keywords

""",
                height=650
            )

    # ==========================================
    # BUTTON EVENT
    # ==========================================

    summarize_btn.click(
        fn=summarize,
        inputs=pdf,
        outputs=output,
        show_progress="full"
    )

    # ==========================================
    # FOOTER
    # ==========================================

    gr.HTML("""

    <hr style="margin-top:35px;border:1px solid #12344D;">

    <div style="text-align:center;padding:15px;">

        <h3 style="color:#FFD54F;">
            Corporate Research Intelligence Platform
        </h3>

        <p style="font-size:15px;color:#CBD5E1;">

        🚀 Powered by
        <b style="color:#FFD54F;">Groq</b> |
        <b style="color:#14B8A6;">LangChain</b> |
        <b style="color:#FFD54F;">Gradio</b>

        </p>

        <p style="font-size:14px;color:#94A3B8;">
            AI-Powered Research Summarization & Document Intelligence
        </p>

    </div>

    """)

demo.launch(debug=True)
# Out:
# /tmp/ipykernel_865/2431237096.py:1: UserWarning: The parameters have been moved from the Blocks constructor to the launch() method in Gradio 6.0: theme, css. Please pass these parameters to launch() instead.
#   with gr.Blocks(
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. This cell will run indefinitely so that you can see errors and logs. To turn off, set debug=False in launch().
# * Running on public URL: https://acffe7f33155b1dad7.gradio.live
#
# This share link is temporary and will last for up to 1 week (best effort). For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# ...
